# %% [markdown]
# ![Снимок экрана 2020-12-11 105849.jpg](data:image/jpeg;base64,...)

# %%
class Person:
  def __init__(self,age,gender):
    self.age=age
    self.gender=gender

class Employee(Person):
  def __init__(self,age,hours,gender,company="ООО Ромашка"):
    self.hours=hours
    Person.__init__(self,age,gender)
    self.age=age
    self.gender=gender

class Worker(Employee):
  def pay(self):
    return self.hours*200*30

class Engineer(Employee):
  def pay(self):
    return self.hours*400*30

# %%
worker=Worker(36,12,'m')
print("Зарплата рабочего = ",worker.pay(), 'рублей')
engineer=Engineer(36,12,'W')
print("Зарплата инженера = ",engineer.pay(), 'рублей, ведь у него есть высшее образование')
# Out:
# Зарплата рабочего =  72000 рублей
# Зарплата инженера =  144000 рублей, ведь у него есть высшее образование
